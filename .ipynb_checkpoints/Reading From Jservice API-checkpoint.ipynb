# %%
import requests

# %%
responses = []

# %%
for i in range(1,500):
    responses = responses + requests.get("http://jservice.io/api/categories?count=100&offset={}".format(i*100)).json()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2ce9f5d551c7> in <module>
#       1 for i in range(1,500):
# ----> 2     responses = responses + requests.get("http://jservice.io/api/categories?count=100&offset={}".format(i*100)).json()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ...

# %%
requests.get("http://jservice.io/api/categories").json()
# Out:
# [{'id': 11509, 'title': 'little women', 'clues_count': 5}]

# %%
len(responses)
# Out:
# 18316

# %%
responses
# Out:
# [{'id': 11605, 'title': "classical works' other names", 'clues_count': 5},
#  {'id': 8044, 'title': 'in the bible', 'clues_count': 10},
#  {'id': 11508, 'title': 'gullible travels are cool', 'clues_count': 5},
#  {'id': 11594, 'title': 'ride on', 'clues_count': 5},
#  {'id': 11595, 'title': 'sex & the kitty', 'clues_count': 5},
#  {'id': 11596, 'title': 'poison ivy, oak & sumac', 'clues_count': 5},
#  {'id': 3271, 'title': "who played 'em?", 'clues_count': 40},
#  {'id': 11606, 'title': 'as "if"!', 'clues_count': 5},
#  {'id': 11607, 'title': 'whatever!', 'clues_count': 5},
#  {'id': 11622, 'title': 'school mottoes', 'clues_count': 5},
#  {'id': 11623, 'title': 'country name etymology', 'clues_count': 5},
#  {'id': 11583, 'title': 'america the beautiful', 'clues_count': 5},
#  {'id': 11584, 'title': 'movie remakes', 'clues_count': 5},
#  {'id': 11585, 'title': 'this, or that', 'clues_count': 5},
#  {'id': 11586, 'title': 'a world of music', 'clues_count': 5},
# ...

# %%
total = 0
for response in responses:
    total += response["clues_count"]

# %%
print(total)
# Out:
# 3702

# %% [markdown]
# # There are 18410 total categories

# %% [markdown]
# ### Plan is to get all the categories from the
#
# #### also i think max and min date are flipped in the api call

# %%
questions = [{'id': 11604, 'title': "ben & jerry's flavors", 'clues_count': 15},
 {'id': 11605, 'title': "classical works' other names", 'clues_count': 5},
 {'id': 8044, 'title': 'in the bible', 'clues_count': 10},
 {'id': 11508, 'title': 'gullible travels are cool', 'clues_count': 5},
 {'id': 11594, 'title': 'ride on', 'clues_count': 5},
 {'id': 11595, 'title': 'sex & the kitty', 'clues_count': 5},
 {'id': 11596, 'title': 'poison ivy, oak & sumac', 'clues_count': 5},
 {'id': 3271, 'title': "who played 'em?", 'clues_count': 40},
 {'id': 11606, 'title': 'as "if"!', 'clues_count': 5},
 {'id': 11607, 'title': 'whatever!', 'clues_count': 5},
 {'id': 11622, 'title': 'school mottoes', 'clues_count': 5},
 {'id': 11623, 'title': 'country name etymology', 'clues_count': 5},
 {'id': 11583, 'title': 'america the beautiful', 'clues_count': 5},
 {'id': 11584, 'title': 'movie remakes', 'clues_count': 5},
 {'id': 11585, 'title': 'this, or that', 'clues_count': 5},
 {'id': 11586, 'title': 'a world of music', 'clues_count': 5},
 {'id': 11587, 'title': 'i feel a bit "ill"', 'clues_count': 5},
 {'id': 11588, 'title': 'take my temperature', 'clues_count': 5},
 {'id': 11624, 'title': 'as quick as you can say...', 'clues_count': 5},
 {'id': 3053, 'title': 'jackie robinson', 'clues_count': 10},
 {'id': 11614, 'title': 'name that june', 'clues_count': 5},
 {'id': 11615, 'title': 'the razzies for 2008', 'clues_count': 5},
 {'id': 11616,
  'title': 'cabinet departments in other words',
  'clues_count': 5},
 {'id': 11617, 'title': 'holmes, sherlock holmes', 'clues_count': 5},
 {'id': 11618, 'title': "here's something random", 'clues_count': 5},
 {'id': 11597, 'title': "it's astronomical!", 'clues_count': 5},
 {'id': 11598, 'title': 'animal words', 'clues_count': 5},
 {'id': 11599, 'title': 'state university alumni', 'clues_count': 5},
 {'id': 11600, 'title': 'historical home shopping', 'clues_count': 5},
 {'id': 847, 'title': 'guinness records', 'clues_count': 90},
 {'id': 11602, 'title': 'royal movies?', 'clues_count': 5},
 {'id': 9245, 'title': 'the new york times book review', 'clues_count': 10},
 {'id': 11589, 'title': 'the puck stops here', 'clues_count': 5},
 {'id': 11590, 'title': 'beastly blues', 'clues_count': 5},
 {'id': 11591, 'title': 'a man called horace', 'clues_count': 5},
 {'id': 11592, 'title': 'potent potables, southern style', 'clues_count': 5},
 {'id': 11593, 'title': '"ker"', 'clues_count': 5},
 {'id': 11619, 'title': 'everything\'s coming up "rose"s', 'clues_count': 5},
 {'id': 11637, 'title': 'potpourri (really)', 'clues_count': 5},
 {'id': 11608, 'title': 'opera crossword clues', 'clues_count': 5},
 {'id': 11609, 'title': 'sports net', 'clues_count': 5},
 {'id': 1317, 'title': "last name's the same", 'clues_count': 80},
 {'id': 11611, 'title': 'look!  up in the sky!', 'clues_count': 5},
 {'id': 11612, 'title': 'so you think you can france', 'clues_count': 5},
 {'id': 11613, 'title': '"bot" of course', 'clues_count': 5},
 {'id': 11638, 'title': 'into africa', 'clues_count': 5},
 {'id': 11639, 'title': 'ancient roman dining', 'clues_count': 5},
 {'id': 11640, 'title': 'going "pro"', 'clues_count': 5},
 {'id': 11648, 'title': 'quotes from the king james bible', 'clues_count': 5},
 {'id': 11625, 'title': 'are you ready for some foosball', 'clues_count': 5},
 {'id': 11626, 'title': 'common computer abbrev.', 'clues_count': 5},
 {'id': 11627, 'title': 'weird scents', 'clues_count': 5},
 {'id': 11610, 'title': 'the heloise with you', 'clues_count': 15},
 {'id': 11628, 'title': '"j" mart', 'clues_count': 5},
 {'id': 9611, 'title': 'he was president when...', 'clues_count': 10},
 {'id': 1036, 'title': 'record labels', 'clues_count': 20},
 {'id': 11641, 'title': 'do-gooders', 'clues_count': 5},
 {'id': 11629, 'title': 'the british are different', 'clues_count': 5},
 {'id': 11630, 'title': 'top 40 commencement addresses?', 'clues_count': 5},
 {'id': 11642, 'title': 'ballets alex could star in', 'clues_count': 5},
 {'id': 11631, 'title': 'obscure america', 'clues_count': 5},
 {'id': 11632, 'title': 'fast food chains in other words', 'clues_count': 5},
 {'id': 11633, 'title': '(whoops)', 'clues_count': 5},
 {'id': 11634, 'title': 'choice 4-letter words', 'clues_count': 5},
 {'id': 11643,
  'title': 'one of these things is not like the others',
  'clues_count': 5},
 {'id': 11665, 'title': 'in florida', 'clues_count': 10},
 {'id': 11635, 'title': "a year ending in '09", 'clues_count': 5},
 {'id': 11636, 'title': 'movies by songs', 'clues_count': 5},
 {'id': 11655, 'title': "'cause i'm going to...", 'clues_count': 5},
 {'id': 11646, 'title': 'bride & gloom', 'clues_count': 5},
 {'id': 11647, 'title': 'a new line of barbies?', 'clues_count': 5},
 {'id': 11601,
  'title': "from the british monarchy's website",
  'clues_count': 15},
 {'id': 2564, 'title': 'crossword clues "f"', 'clues_count': 30},
 {'id': 11649, 'title': 'wimbledon singles champs', 'clues_count': 5},
 {'id': 283, 'title': '12-letter words', 'clues_count': 40},
 {'id': 11650, 'title': 'the literary cheerleader!', 'clues_count': 5},
 {'id': 11651, 'title': 'common rhymes', 'clues_count': 5},
 {'id': 11656, 'title': 'a series of fields', 'clues_count': 5},
 {'id': 11652, 'title': 'name your business', 'clues_count': 5},
 {'id': 11653, 'title': "i'm getting hungry", 'clues_count': 5},
 {'id': 3422, 'title': 'spell it backwards', 'clues_count': 10},
 {'id': 11654, 'title': 'let me take you down', 'clues_count': 5},
 {'id': 11660, 'title': 'the "oc"', 'clues_count': 5},
 {'id': 11657, 'title': 'welcome to lisbon', 'clues_count': 5},
 {'id': 11659, 'title': 'tailgate cuisine', 'clues_count': 5},
 {'id': 6250, 'title': 'is there a doctor in the house?', 'clues_count': 10},
 {'id': 11658, 'title': 'come fly with me', 'clues_count': 5},
 {'id': 754, 'title': 'anagrams', 'clues_count': 91},
 {'id': 11662, 'title': 'fun with letters', 'clues_count': 5},
 {'id': 11663, 'title': 'uppers & downers', 'clues_count': 5},
 {'id': 11664, 'title': 'i killed a guy once', 'clues_count': 5},
 {'id': 3023, 'title': 'name calling', 'clues_count': 20},
 {'id': 11687, 'title': 'silent partners', 'clues_count': 5},
 {'id': 5031, 'title': 'the day the music died', 'clues_count': 10},
 {'id': 11688, 'title': "it's chinatown, jake", 'clues_count': 5},
 {'id': 5625, 'title': 'broadway debuts', 'clues_count': 25},
 {'id': 11661, 'title': '"a____a" in the atlas', 'clues_count': 5},
 {'id': 4381, 'title': '2 first names?', 'clues_count': 10},
 {'id': 11675, 'title': 'not hard at all', 'clues_count': 5},
 {'id': 11676, 'title': 'easy street', 'clues_count': 5},
 {'id': 11677, 'title': "child's play", 'clues_count': 5},
 {'id': 11678, 'title': 'duck! soup', 'clues_count': 5},
 {'id': 11679, 'title': 'in the bag', 'clues_count': 5},
 {'id': 11680, 'title': 'it\'s a "snap"', 'clues_count': 5},
 {'id': 11689, 'title': 'angry moms of future presidents', 'clues_count': 5},
 {'id': 1189, 'title': 'similes', 'clues_count': 15},
 {'id': 11666, 'title': "that's historic", 'clues_count': 5},
 {'id': 11667, 'title': 'toon tunes', 'clues_count': 5},
 {'id': 11668, 'title': 'cop talk', 'clues_count': 5},
 {'id': 11669, 'title': '"utter" your response', 'clues_count': 5},
 {'id': 2752, 'title': '15 minutes of fame', 'clues_count': 25},
 {'id': 11719, 'title': 'how inventive', 'clues_count': 5},
 {'id': 211, 'title': 'bodies of water', 'clues_count': 165},
 {'id': 11699, 'title': 'presidents & vice presidents', 'clues_count': 15},
 {'id': 11696, 'title': 'rhyming product names', 'clues_count': 5},
 {'id': 11697, 'title': 'alexander', 'clues_count': 5},
 {'id': 11698, 'title': 'the "great"', 'clues_count': 5},
 {'id': 11720, 'title': 'absolute adjectives', 'clues_count': 5},
 {'id': 11721, 'title': 'the new york times technology', 'clues_count': 5},
 {'id': 11681, 'title': "let's go to italy", 'clues_count': 5},
 {'id': 11682, 'title': 'revolving restaurants', 'clues_count': 5},
 {'id': 11683, 'title': 'on board game boards', 'clues_count': 5},
 {'id': 11684, 'title': 'the "anti"-category', 'clues_count': 5},
 {'id': 11685, 'title': 'miro, miro on the wall', 'clues_count': 5},
 {'id': 11734,
  'title': 'sports illustrated sportsman of the year',
  'clues_count': 15},
 {'id': 11670, 'title': "hollywouldn't", 'clues_count': 5},
 {'id': 11671, 'title': 'dog-eared pages', 'clues_count': 5},
 {'id': 11672, 'title': 'nautical rhyme time', 'clues_count': 5},
 {'id': 11673, 'title': 'june 5 babies', 'clues_count': 5},
 {'id': 11674, 'title': "what's your function?", 'clues_count': 5},
 {'id': 11686, 'title': "who's the fairest one of all?", 'clues_count': 5},
 {'id': 11722, 'title': 'the world at war', 'clues_count': 5},
 {'id': 11723, 'title': 'fruit of the klum', 'clues_count': 5},
 {'id': 5213, 'title': 'wars by battle', 'clues_count': 20},
 {'id': 11690, 'title': 'celebrity anecdotes', 'clues_count': 5},
 {'id': 11691, 'title': 'hidden agenda', 'clues_count': 5},
 {'id': 11692, 'title': 'you are very subtractive', 'clues_count': 5},
 {'id': 11693, 'title': 'mmm...donuts', 'clues_count': 5},
 {'id': 11694, 'title': '"i" openers', 'clues_count': 5},
 {'id': 11724, 'title': 'also a canterbury tales pilgrim', 'clues_count': 5},
 {'id': 11725,
  'title': 'oh, what a tangled website we weave',
  'clues_count': 5},
 {'id': 11710, 'title': 'what a knockout!', 'clues_count': 5},
 {'id': 11711, 'title': 'literary movements', 'clues_count': 5},
 {'id': 622, 'title': 'holidays & observances', 'clues_count': 195},
 {'id': 11704, 'title': 'first female leaders', 'clues_count': 5},
 {'id': 11705,
  'title': "rolling stone's 100 greatest singers",
  'clues_count': 5},
 {'id': 11706, 'title': 'advertising icons', 'clues_count': 5},
 {'id': 11707, 'title': "states' geographic centers", 'clues_count': 5},
 {'id': 1195, 'title': 'number, please', 'clues_count': 105},
 {'id': 11700, 'title': 'the dallas cowboys', 'clues_count': 5},
 {'id': 11701, 'title': 'car brands by emblem', 'clues_count': 5},
 {'id': 11702, 'title': 'founders', 'clues_count': 5},
 {'id': 11703, 'title': 'news from the 21st century', 'clues_count': 5},
 {'id': 11708, 'title': 'a sneezy category', 'clues_count': 5},
 {'id': 11709, 'title': '"atch", you!', 'clues_count': 5},
 {'id': 11712,
  'title': 'historical military therapy sessions',
  'clues_count': 5},
 {'id': 4237, 'title': 'u.s. stamps', 'clues_count': 36},
 {'id': 11713, 'title': 'also a dog command', 'clues_count': 5},
 {'id': 11726, 'title': 'hobo a go go', 'clues_count': 5},
 {'id': 11727, 'title': 'riding the "rail"s', 'clues_count': 5},
 {'id': 7191, 'title': 'native american place names', 'clues_count': 15},
 {'id': 11714, 'title': 'the human animal', 'clues_count': 5},
 {'id': 11729, 'title': 'vampires are everywhere', 'clues_count': 5},
 {'id': 11715, 'title': "time's top 10 everything of 2008", 'clues_count': 5},
 {'id': 11716, 'title': 'scrambled eggs', 'clues_count': 5},
 {'id': 3865, 'title': 'truth or dare', 'clues_count': 10},
 {'id': 11717, 'title': 'beach volleyball', 'clues_count': 5},
 {'id': 11718, 'title': 'their first top 10 solo hit', 'clues_count': 5},
 {'id': 10466, 'title': 'at the drugstore', 'clues_count': 45},
 {'id': 11730, 'title': '20th century news', 'clues_count': 5},
 {'id': 11731, 'title': "that's criminal!", 'clues_count': 5},
 {'id': 11732, 'title': '"road" test', 'clues_count': 5},
 {'id': 11736, 'title': 'hybrid poodles', 'clues_count': 5},
 {'id': 11728, 'title': 'the special olympics', 'clues_count': 5},
 {'id': 11737, 'title': 'marcus', 'clues_count': 5},
 {'id': 11733, 'title': 'a potent potable tour', 'clues_count': 5},
 {'id': 11735, 'title': 'oh, shaw!', 'clues_count': 5},
 {'id': 11738, 'title': 'well, "b"!', 'clues_count': 5},
 {'id': 11743,
  'title': 'stupid answers: the british edition',
  'clues_count': 5},
 {'id': 11744,
  'title': 'the national museum of the marine corps',
  'clues_count': 5},
 {'id': 11739, 'title': 'colonialism in africa', 'clues_count': 5},
 {'id': 11740, 'title': 'fictional games', 'clues_count': 5},
 {'id': 11741, 'title': 'restaurant lingo', 'clues_count': 5},
 {'id': 11742, 'title': 'states by state parks', 'clues_count': 5},
 {'id': 6838, 'title': 'a river runs through it', 'clues_count': 20},
 {'id': 11745, 'title': 'getting your actor together', 'clues_count': 5},
 {'id': 11746, 'title': 'scintillating syllabus', 'clues_count': 5},
 {'id': 11747, 'title': 'missing words', 'clues_count': 5},
 {'id': 11695, 'title': 'fun with numbers', 'clues_count': 10},
 {'id': 10024, 'title': 'what are you afraid of?', 'clues_count': 30},
 {'id': 10306, 'title': 'the sporting life', 'clues_count': 25},
 {'id': 11194, 'title': 'fun with fashion', 'clues_count': 10},
 {'id': 11781, 'title': 'how many players on each side?', 'clues_count': 5},
 {'id': 11759, 'title': 'fun with science', 'clues_count': 5},
 {'id': 11760, 'title': 'tv geography', 'clues_count': 5},
 {'id': 11761, 'title': "kickin' it old school", 'clues_count': 5},
 {'id': 11762, 'title': "cities' newer names", 'clues_count': 5},
 {'id': 11763, 'title': 'you\'re a "q____t"', 'clues_count': 5},
 {'id': 11782,
  'title': "you can't spell jeopardy! without party!",
  'clues_count': 5},
 {'id': 11783, 'title': 'schools named after people', 'clues_count': 5},
 {'id': 9838, 'title': 'college-podge', 'clues_count': 15},
 {'id': 11773, 'title': 'place name partners', 'clues_count': 5},
 {'id': 11774, 'title': 'psych!', 'clues_count': 5},
 {'id': 11775, 'title': '"back" to school', 'clues_count': 5},
 {'id': 11748, 'title': 'at bay', 'clues_count': 5},
 {'id': 11749, 'title': 'pop goes the category', 'clues_count': 5},
 {'id': 11750, 'title': 'hookups', 'clues_count': 5},
 {'id': 11751, 'title': 'asserting author-ity', 'clues_count': 5},
 {'id': 11753, 'title': 'one-button text messaging', 'clues_count': 5},
 {'id': 11764, 'title': 'the 21st century with cnn', 'clues_count': 5},
 {'id': 11765, 'title': 'name that game show', 'clues_count': 5},
 {'id': 11752, 'title': 'econ 101', 'clues_count': 15},
 {'id': 11766, 'title': 'take a "shot"', 'clues_count': 5},
 {'id': 11803, 'title': "the greek god's roman name", 'clues_count': 5},
 {'id': 11804, 'title': 'fictional munchies', 'clues_count': 5},
 {'id': 11805, 'title': "grandma's lotto numbers", 'clues_count': 5},
 {'id': 11806, 'title': 'fish tales', 'clues_count': 5},
 {'id': 11807, 'title': 'alex rocks in concert', 'clues_count': 5},
 {'id': 11808, 'title': '"b" fore & after', 'clues_count': 5},
 {'id': 11754, 'title': 'staying at home', 'clues_count': 5},
 {'id': 11755, 'title': 'the world comes to you', 'clues_count': 5},
 {'id': 11386, 'title': "what's on tv?", 'clues_count': 10},
 {'id': 11756, 'title': 'check the newspaper', 'clues_count': 5},
 {'id': 11757, 'title': 'take out the trash', 'clues_count': 5},
 {'id': 11758, 'title': 'time for a "nap"', 'clues_count': 5},
 {'id': 7341, 'title': 'sweet stuff', 'clues_count': 25},
 {'id': 3880, 'title': 'name the shakespeare play', 'clues_count': 10},
 {'id': 11792, 'title': 'political nicknames', 'clues_count': 5},
 {'id': 11793, 'title': 'movies in minivans', 'clues_count': 5},
 {'id': 11794, 'title': 'ad wear', 'clues_count': 5},
 {'id': 11788, 'title': "tra-la!  it's may!", 'clues_count': 5},
 {'id': 11776, 'title': 'the lady swings', 'clues_count': 5},
 {'id': 11777, 'title': 'would you like flies with that?', 'clues_count': 5},
 {'id': 11778, 'title': 'fast friends', 'clues_count': 5},
 {'id': 11779, 'title': "it's elementary", 'clues_count': 5},
 {'id': 11780, 'title': 'computer rhyme time', 'clues_count': 5},
 {'id': 11767, 'title': 'old folks in their 30s', 'clues_count': 5},
 {'id': 11768, 'title': 'movies & tv', 'clues_count': 5},
 {'id': 11769, 'title': 'a state of college-ness', 'clues_count': 5},
 {'id': 11770, 'title': 'animal collective', 'clues_count': 5},
 {'id': 11771, 'title': "i'd rather be skiing", 'clues_count': 5},
 {'id': 11772, 'title': 'parlez vous?', 'clues_count': 5},
 {'id': 11790, 'title': 'military installations by state', 'clues_count': 5},
 {'id': 5970, 'title': 'the fortune 500', 'clues_count': 15},
 {'id': 11791, 'title': 'in the encyclopedia', 'clues_count': 5},
 {'id': 11784, 'title': 'name the work', 'clues_count': 5},
 {'id': 11785, 'title': 'heisman winners', 'clues_count': 5},
 {'id': 11786, 'title': 'i want to ride that!', 'clues_count': 5},
 {'id': 10937, 'title': 'a horse is a horse', 'clues_count': 10},
 {'id': 11787, 'title': 'rhymes with track', 'clues_count': 5},
 {'id': 11795, 'title': "you're a jeopardy! fan if\x85", 'clues_count': 5},
 {'id': 11796, 'title': 'purple prose & poetry', 'clues_count': 5},
 {'id': 11797, 'title': 'also a color', 'clues_count': 5},
 {'id': 11798, 'title': 'i married a beatle', 'clues_count': 5},
 {'id': 11799, 'title': 'darth vader, d.d.s.', 'clues_count': 5},
 {'id': 11800, 'title': '"g"', 'clues_count': 5},
 {'id': 11801, 'title': 'your hair', 'clues_count': 5},
 {'id': 11802, 'title': 'smells terrific', 'clues_count': 5},
 {'id': 508, 'title': 'common bonds', 'clues_count': 215},
 {'id': 11789, 'title': 'name that prez', 'clues_count': 10},
 {'id': 11846, 'title': 'the battle of bull run', 'clues_count': 5},
 {'id': 11847, 'title': 'movies any time', 'clues_count': 5},
 {'id': 1345, 'title': 'genesis', 'clues_count': 40},
 {'id': 11849, 'title': 'your college i.d.', 'clues_count': 5},
 {'id': 11850, 'title': 'dictionary abbr.', 'clues_count': 5},
 {'id': 11858, 'title': 'guinness', 'clues_count': 15},
 {'id': 11809, 'title': 'aaron spelling bee', 'clues_count': 5},
 {'id': 11810, 'title': 'imbiblers', 'clues_count': 5},
 {'id': 11173, 'title': 'spheres', 'clues_count': 10},
 {'id': 11811, 'title': 'animated word puzzles', 'clues_count': 5},
 {'id': 11821, 'title': 'best actress oscar by film', 'clues_count': 5},
 {'id': 11822, 'title': 'fun with eponyms', 'clues_count': 5},
 {'id': 11823, 'title': 'the new york times times machine', 'clues_count': 5},
 {'id': 11824, 'title': 'quasi-stupid answers', 'clues_count': 5},
 {'id': 11825, 'title': 'ahd negative prefixes', 'clues_count': 5},
 {'id': 11831, 'title': 'behind the seuss-ic', 'clues_count': 5},
 {'id': 11832, 'title': 'the celebrity bling biz', 'clues_count': 5},
 {'id': 11833, 'title': 'name their island chain', 'clues_count': 5},
 {'id': 11834, 'title': 'secret service code names 2009', 'clues_count': 5},
 {'id': 11812, 'title': 'sounds like a sneeze', 'clues_count': 5},
 {'id': 11813, 'title': "the president's first 100 days", 'clues_count': 5},
 {'id': 11814, 'title': 'paddle', 'clues_count': 5},
 {'id': 11815, 'title': 'i hear banjos', 'clues_count': 5},
 {'id': 11835, 'title': 'not literally', 'clues_count': 5},
 {'id': 11836, 'title': 'foreign language', 'clues_count': 5},
 {'id': 11863,
  'title': 'a priest, an elephant & evel knievel...',
  'clues_count': 5},
 {'id': 11864, 'title': 'walk into a "bar"', 'clues_count': 5},
 {'id': 11865, 'title': 'the bartender says...', 'clues_count': 5},
 {'id': 11866, 'title': 'what is this, some kind of joke?', 'clues_count': 5},
 {'id': 11851, 'title': 'band debuts by decade', 'clues_count': 10},
 {'id': 11843, 'title': 'unwritten dining-out rules', 'clues_count': 5},
 {'id': 11844, 'title': 'popcorn colonels', 'clues_count': 5},
 {'id': 11816, 'title': 'big fan', 'clues_count': 5},
 {'id': 11817, 'title': "that's not where you think it is", 'clues_count': 5},
 {'id': 9251, 'title': 'the new york times business', 'clues_count': 15},
 {'id': 11818, 'title': 'the most wanted list', 'clues_count': 5},
 {'id': 11819, 'title': 'anagrams of compass directions', 'clues_count': 5},
 {'id': 8277, 'title': 'the nature of the beast', 'clues_count': 10},
 {'id': 11826, 'title': 'wonders of the midwest', 'clues_count': 5},
 {'id': 11827, 'title': "tv's gone but not forgotten", 'clues_count': 5},
 {'id': 5318, 'title': 'the butler did it', 'clues_count': 10},
 {'id': 11845, 'title': 'body english', 'clues_count': 5},
 {'id': 11828, 'title': "texas hold'em hands", 'clues_count': 5},
 {'id': 11829,
  'title': 'birthstones... meet the birthstones',
  'clues_count': 5},
 {'id': 11830, 'title': 'yabba dabba "doo"!', 'clues_count': 5},
 {'id': 11873, 'title': 'there once was this man from...', 'clues_count': 5},
 {'id': 11874, 'title': 'this will slay you', 'clues_count': 5},
 {'id': 11875, 'title': "it's a country thing", 'clues_count': 5},
 {'id': 11876, 'title': 'name that mammal', 'clues_count': 5},
 {'id': 11877, 'title': 'modern technology', 'clues_count': 5},
 {'id': 11878, 'title': 'words from places', 'clues_count': 5},
 {'id': 456, 'title': 'crime', 'clues_count': 5},
 {'id': 11837, 'title': 'joe the plumber', 'clues_count': 5},
 {'id': 11838, 'title': 'the office games', 'clues_count': 5},
 {'id': 11839, 'title': 'biblical non-prophet', 'clues_count': 5},
 {'id': 11840, 'title': 'just a "sec"!', 'clues_count': 5},
 {'id': 11841, 'title': 'the report of my death...', 'clues_count': 5},
 {'id': 11842, 'title': "it's not so", 'clues_count': 5},
 {'id': 11867, 'title': "in joe paterno's first year", 'clues_count': 5},
 {'id': 11856, 'title': 'rolling rock', 'clues_count': 5},
 {'id': 11857, 'title': 'sam adams', 'clues_count': 5},
 {'id': 6021, 'title': '"up" words', 'clues_count': 20},
 {'id': 11859, 'title': 'st. paul-y girl', 'clues_count': 5},
 {'id': 11860, 'title': '"bud"', 'clues_count': 5},
 {'id': 11848, 'title': 'top seller in the u.s.', 'clues_count': 10},
 {'id': 11852, 'title': 'scandalous nursery rhymes', 'clues_count': 5},
 {'id': 11853, 'title': '"c"ooking', 'clues_count': 5},
 {'id': 11854, 'title': 'some call it blasphemy', 'clues_count': 5},
 {'id': 11855, 'title': 'alphabetically last letter', 'clues_count': 5},
 {'id': 11868, 'title': 'books that became films', 'clues_count': 5},
 {'id': 11869, 'title': 'prepositions', 'clues_count': 5},
 {'id': 11870, 'title': 'fortune-telling', 'clues_count': 5},
 {'id': 11861, 'title': 'the novel list', 'clues_count': 5},
 {'id': 11862,
  'title': 'the new york times: arts & leisure',
  'clues_count': 5},
 {'id': 11879, 'title': 'presidential potent potables', 'clues_count': 5},
 {'id': 11871, 'title': 'this, that', 'clues_count': 5},
 {'id': 11872, 'title': 'the other', 'clues_count': 5},
 {'id': 11880, 'title': '2027: the year in entertainment', 'clues_count': 5},
 {'id': 11881, 'title': 'waist management', 'clues_count': 5},
 {'id': 1724, 'title': 'discoveries', 'clues_count': 10},
 {'id': 11820, 'title': 'religions', 'clues_count': 15},
 {'id': 11886, 'title': 'central park statues', 'clues_count': 5},
 {'id': 7934, 'title': 'the last', 'clues_count': 10},
 {'id': 11882, 'title': '2 "b" or not 2 "b"', 'clues_count': 5},
 {'id': 11883, 'title': 'snl actors & their characters', 'clues_count': 5},
 {'id': 11885, 'title': "good o'men", 'clues_count': 5},
 {'id': 11884, 'title': 'movable feasts', 'clues_count': 5},
 {'id': 11891, 'title': 'british bands', 'clues_count': 5},
 {'id': 3336, 'title': 'the cold war', 'clues_count': 20},
 {'id': 11887, 'title': 'culture club', 'clues_count': 5},
 {'id': 11888, 'title': 'bananarama', 'clues_count': 5},
 {'id': 11889, 'title': 'the clash', 'clues_count': 5},
 {'id': 11890, 'title': 'yes', 'clues_count': 5},
 {'id': 11894, 'title': 'record of the year grammys', 'clues_count': 15},
 {'id': 11892, 'title': 'geek chic', 'clues_count': 5},
 {'id': 11893, 'title': 'su-su-sushi-o', 'clues_count': 5},
 {'id': 11895, 'title': 'the "end" zone', 'clues_count': 5},
 {'id': 11924, 'title': 'vegas films', 'clues_count': 5},
 {'id': 5857, 'title': "the play's the thing", 'clues_count': 10},
 {'id': 11925, 'title': 'at the buffet', 'clues_count': 5},
 {'id': 11926, 'title': 'flooring', 'clues_count': 5},
 {'id': 11927, 'title': "rebellions: shays' & whiskey", 'clues_count': 5},
 {'id': 11906, 'title': 'musical heart conditions', 'clues_count': 5},
 {'id': 2214, 'title': 'authors & their sleuths', 'clues_count': 10},
 {'id': 11907, 'title': 'personal fowls', 'clues_count': 5},
 {'id': 11908, 'title': "i'm latin intolerant", 'clues_count': 5},
 {'id': 11909, 'title': 'the end of the marathon', 'clues_count': 5},
 {'id': 11928, 'title': 'poetic words', 'clues_count': 5},
 {'id': 1800, 'title': 'before & after', 'clues_count': 105},
 {'id': 11957, 'title': 'prez dispensers', 'clues_count': 5},
 {'id': 11945, 'title': '18th century literature', 'clues_count': 5},
 {'id': 11940, 'title': 'a storied history', 'clues_count': 5},
 {'id': 11896, 'title': 'rome, the eternal city', 'clues_count': 5},
 {'id': 11897,
  'title': '& the 21st century emmy goes to...',
  'clues_count': 5},
 {'id': 11898, 'title': 'when politicians speak', 'clues_count': 5},
 {'id': 8817, 'title': 'i want my suv', 'clues_count': 10},
 {'id': 11899, 'title': 'stephen, king of writing', 'clues_count': 5},
 {'id': 11900,
  'title': 'the new york times crossword puzzle',
  'clues_count': 5},
 {'id': 11956, 'title': 'classic albums', 'clues_count': 15},
 {'id': 11942, 'title': 'other places to gamble', 'clues_count': 5},
 {'id': 11943, 'title': 'writers on film', 'clues_count': 5},
 {'id': 11944, 'title': 'words in tournament', 'clues_count': 5},
 {'id': 11910, 'title': 'broadway musical adjectives', 'clues_count': 5},
 {'id': 11911, 'title': 'march', 'clues_count': 5},
 {'id': 11912, 'title': 'in like a lion', 'clues_count': 5},
 {'id': 11913, 'title': 'out like a "lam"', 'clues_count': 5},
 {'id': 4133, 'title': 'the sopranos', 'clues_count': 10},
 {'id': 11920, 'title': 'battles by present-day country', 'clues_count': 5},
 {'id': 2077, 'title': '1961', 'clues_count': 20},
 {'id': 11902, 'title': 'tricky stupid answers', 'clues_count': 5},
 {'id': 11903, 'title': 'an "o\'" category', 'clues_count': 5},
 {'id': 11904, 'title': "maybe we'll invade britain!", 'clues_count': 5},
 {'id': 11905, 'title': "that's not cricket", 'clues_count': 5},
 {'id': 11921, 'title': 'email etiquette', 'clues_count': 5},
 {'id': 11922, 'title': 'dumb stuff i saw on the road', 'clues_count': 5},
 {'id': 11923, 'title': 'tasmania mania', 'clues_count': 5},
 {'id': 11934, 'title': '"a" travel category', 'clues_count': 5},
 {'id': 11935, 'title': 'get out your bibles', 'clues_count': 5},
 {'id': 11936, 'title': 'architectural words (& hints)', 'clues_count': 5},
 {'id': 11937, 'title': 'poking around space', 'clues_count': 5}]

# %%
list(filter(lambda question: question['title'] == 'poking around space', questions))
# Out:
# [{'id': 11937, 'title': 'poking around space', 'clues_count': 5}]

# %%
list(filter(lambda question: 'a' in question['title'], questions))
# Out:
# [{'id': 11604, 'title': "ben & jerry's flavors", 'clues_count': 15},
#  {'id': 11605, 'title': "classical works' other names", 'clues_count': 5},
#  {'id': 11508, 'title': 'gullible travels are cool', 'clues_count': 5},
#  {'id': 11596, 'title': 'poison ivy, oak & sumac', 'clues_count': 5},
#  {'id': 3271, 'title': "who played 'em?", 'clues_count': 40},
#  {'id': 11606, 'title': 'as "if"!', 'clues_count': 5},
#  {'id': 11607, 'title': 'whatever!', 'clues_count': 5},
#  {'id': 11623, 'title': 'country name etymology', 'clues_count': 5},
#  {'id': 11583, 'title': 'america the beautiful', 'clues_count': 5},
#  {'id': 11584, 'title': 'movie remakes', 'clues_count': 5},
#  {'id': 11585, 'title': 'this, or that', 'clues_count': 5},
#  {'id': 11586, 'title': 'a world of music', 'clues_count': 5},
#  {'id': 11587, 'title': 'i feel a bit "ill"', 'clues_count': 5},
#  {'id': 11588, 'title': 'take my temperature', 'clues_count': 5},
# ...

# %%
len(responses)
type(responses)
responses = responses

# %%
results = list(filter(lambda question: question['title']!= None and'a' in question['title'], responses))

# %%
# Out:
# 11901

# %%
# Out:
# 18316
